# %% [markdown]
# # 2021-03-29
#
# The goal of this notebook is to test out convolution of a binary spike trian with a guassin & then edit the PWM analysis code to implment htis

# %%
import numpy as np
import numpy.random as npr
import matplotlib.pyplot as plt
from scipy.stats import norm
from scipy.ndimage.filters import gaussian_filter1d

# %%
def gaussian(x, mu, sigma):
    return 1 / (sigma * np.sqrt(2 * np.pi)) * np.exp(-1/2 * ((x - mu)/sigma)**2)

# %%
mu = 0
sigma = .150

x = np.linspace(-1.0, 1.0, 150)
kernal = gaussain(x, mu, sigma)
kernal_normalized = kernal/np.sum(kernal)
plt.plot(x, kernal)

# %%
from scipy.integrate import simps
simps(kernal, dx = 0.001)
# Out:
# 0.07449999999807183

# %%
spike_train = npr.rand(300)
spike_train = np.where(spike_train < 0.5, 0, 1)

# %%
fig, ax = plt.subplots(figsize = (15, 5))
plt.plot(spike_train)
plt.plot(np.convolve(spike_train, kernal))
